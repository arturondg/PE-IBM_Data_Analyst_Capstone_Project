# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Visualize the distribution of data.
#
# *   Visualize the relationship between two features.
#
# *   Visualize composition of data.
#
# *   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2022-12-31 00:04:12--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: ‘m4_survey_data.sqlite.1’
#
# m4_survey_data.sqli 100%[===================>]  34.98M  11.9MB/s    in 2.9s
#
# 2022-12-31 00:04:16 (11.9 MB/s) - ‘m4_survey_data.sqlite.1’ saved [36679680/36679680]

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# 54  72.0      1
# 55  99.0      1

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
#   "OffOn" TEXT,
#   "SocialMedia" TEXT,
#   "Extraversion" TEXT,
#   "ScreenName" TEXT,
#   "SOVisit1st" TEXT,
#   "SOVisitFreq" TEXT,
#   "SOFindAnswer" TEXT,
#   "SOTimeSaved" TEXT,
#   "SOHowMuchTime" TEXT,
#   "SOAccount" TEXT,
#   "SOPartFreq" TEXT,
#   "SOJobs" TEXT,
#   "EntTeams" TEXT,
#   "SOComm" TEXT,
#   "WelcomeChange" TEXT,
#   "Age" REAL,
#   "Trans" TEXT,
#   "Dependents" TEXT,
#   "SurveyLength" TEXT,
#   "SurveyEase" TEXT
# )

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %%
# your code goes here
QUERY = """
SELECT *
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    index  Respondent                      MainBranch Hobbyist  \
# 0      0           4  I am a developer by profession       No
# 1      1           9  I am a developer by profession      Yes
# 2      2          13  I am a developer by profession      Yes
# 3      3          16  I am a developer by profession      Yes
# 4      4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 3  The quality of OSS and closed source software ...  Employed full-time
# 4  The quality of OSS and closed source software ...  Employed full-time
#
#           Country Student                                            EdLevel  \
# 0   United States      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1     New Zealand      No  Some college/university study without earning ...
# 2   United States      No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 3  United Kingdom      No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4       Australia      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#    ...                           SOPartFreq  \
# 0  ...  Less than once per month or monthly
# 1  ...  Less than once per month or monthly
# 2  ...  Less than once per month or monthly
# 3  ...  Less than once per month or monthly
# 4  ...                 A few times per week
#
#                                               SOJobs  \
# 0                                                Yes
# 1  No, I knew that Stack Overflow had a job board...
# 2                                                Yes
# 3                                                Yes
# 4  No, I didn't know that Stack Overflow had a jo...
#
#                                             EntTeams          SOComm  \
# 0                No, and I don't know what those are  No, not really
# 1                No, and I don't know what those are   Yes, somewhat
# 2  No, I've heard of them, but I am not part of a...         Neutral
# 3  No, I've heard of them, but I am not part of a...   Yes, somewhat
# 4  No, I've heard of them, but I am not part of a...   Yes, somewhat
#
#                               WelcomeChange   Age Trans Dependents  \
# 0   Just as welcome now as I felt last year  22.0    No         No
# 1   Just as welcome now as I felt last year  23.0    No         No
# 2  Somewhat more welcome now than last year  28.0    No        Yes
# 3   Just as welcome now as I felt last year  26.0    No         No
# 4   Just as welcome now as I felt last year  29.0    No         No
#
#             SurveyLength                  SurveyEase
# 0  Appropriate in length                        Easy
# 1  Appropriate in length  Neither easy nor difficult
# 2  Appropriate in length                        Easy
# 3  Appropriate in length  Neither easy nor difficult
# 4  Appropriate in length                        Easy
#
# [5 rows x 63 columns]

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# your code goes here
df['ConvertedComp'].plot(kind='hist')
plt.title('Histogram of Salary')
plt.ylabel('Salary')
plt.xlabel('Distribution')
plt.show()

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
# your code goes here
import seaborn as sns
sns.boxplot(y="Age", data=df)
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
df['Age'].plot(kind='box', figsize=(3,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
# your code goes here
df.plot(kind='scatter', x='Age', y='WorkWeekHrs')
plt.title('Hours Worked per Week by Age')
plt.xlabel('Age')
plt.ylabel('Hours Worked')
plt.show()

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
# your code goes here
sns.scatterplot(data=df, x='WorkWeekHrs', y='CodeRevHrs', size='Age', hue='Age', alpha=0.7, sizes=(10, 500)) 

plt.title('WorkWeekHrs and CodeRevHrs By Age', size=14) 
plt.xlabel('WorkWeekHrs', size=10) 
plt.ylabel('CodeRevHrs', size=10)
# Out:
# Text(0, 0.5, 'CodeRevHrs')

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
QUERY = """
SELECT DatabaseDesireNextYear, COUNT(*) as count 
from DatabaseDesireNextYear 
group by DatabaseDesireNextYear 
order by count(DatabaseDesireNextYear) DESC LIMIT 5 
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df_df1=pd.read_sql_query(QUERY,conn)  
df_df1.set_index('DatabaseDesireNextYear', inplace=True)

# %%
df_df1
# Out:
#                         count
# DatabaseDesireNextYear
# PostgreSQL               4328
# MongoDB                  3649
# Redis                    3331
# MySQL                    3281
# Elasticsearch            2856

# %%
# your code goes here
#df_df1 = df_db.groupby('DatabaseDesireNextYear', axis= 0).count()
df_df1['count'].plot(kind='pie',
                            figsize=(15, 8),
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (Africa)
                            shadow=False,
                          labels=None,
                          pctdistance=1.1
                            )

plt.title('Database they want to work on next year')
plt.axis('equal')
plt.legend(labels=df_df1.index, loc='upper left') 

plt.show()

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
# your code goes here

QUERY = """
SELECT WorkWeekHrs, CodeRevHrs, Age FROM master
WHERE Age BETWEEN 30 AND 35
"""
df3 = pd.read_sql_query(QUERY,conn)
dfSC = df3.groupby('Age').median()

dfSC.plot(kind='bar', figsize=(10, 6), stacked=True)

plt.title('Stacked Bar Chart of Median WorkWeekHrs and CodeRevHrs for Those Age 30 to 35')
plt.show()

# %%
dfSC
# Out:
#       WorkWeekHrs  CodeRevHrs
# Age
# 30.0         40.0         4.0
# 31.0         40.0         4.0
# 32.0         40.0         4.0
# 33.0         40.0         4.0
# 34.0         40.0         4.0
# 35.0         40.0         4.0

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
# your code goes here
QUERY = """
SELECT ConvertedComp, Age FROM master
WHERE Age BETWEEN 45 AND 60
"""
df7 = pd.read_sql_query(QUERY,conn)
dfLC = df7.groupby('Age').median()
dfLC.plot(kind='line', figsize=(18, 6))
plt.title('Median ConvertedComp for Those Age 45 to 60')
plt.ylabel('ConvertedComp')
plt.show()

# %%
QUERY = """
SELECT ConvertedComp, Age FROM master
WHERE Age BETWEEN 25 AND 30
"""
df7 = pd.read_sql_query(QUERY,conn)
dfLC2 = df7.groupby('Age').median()
dfLC2.plot(kind='line', figsize=(18, 6))
plt.title('Median ConvertedComp for Those Age 25 to 30')
plt.ylabel('ConvertedComp')
plt.show()

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
# your code goes here
dfBC = pd.DataFrame(df['MainBranch'].value_counts())
dfBC.plot(kind='barh')
plt.title('Horizontal Bar Chart for Main Branch')
plt.ylabel('Description')
plt.xlabel('Count')
plt.show()

# %%
QUERY = """
SELECT LanguageDesireNextYear, COUNT(*) as count 
from LanguageDesireNextYear 
group by LanguageDesireNextYear 
order by count(LanguageDesireNextYear) DESC LIMIT 5 
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df_L=pd.read_sql_query(QUERY,conn)  
df_L.set_index('LanguageDesireNextYear', inplace=True) 
df_L
# Out:
#                         count
# LanguageDesireNextYear
# JavaScript               6630
# HTML/CSS                 5328
# Python                   5239
# SQL                      5012
# TypeScript               4088

# %%
df_L['count'].plot(kind='barh', figsize=(9, 6))
plt.title('Top 5 most desired languages for next year')
plt.ylabel('Languages')
plt.xlabel('Count')

for index, value in enumerate(df_L['count']):
    label = format(int(value), ',') 
    plt.annotate(label, xy=(value - 800, index - 0.10), color='white')

#plt.show()
plt.savefig("Top5NY.jpg",  bbox_inches='tight', pad_inches= 1, format='eps', dpi=300)

# %%
QUERY = """
SELECT LanguageWorkedWith, COUNT(*) as count 
from LanguageWorkedWith 
group by LanguageWorkedWith 
order by count(LanguageWorkedWith) DESC LIMIT 5 
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df_Lo=pd.read_sql_query(QUERY,conn)  
df_Lo.set_index('LanguageWorkedWith', inplace=True) 
df_Lo
# Out:
#                        count
# LanguageWorkedWith
# JavaScript              8687
# HTML/CSS                7830
# SQL                     7106
# Bash/Shell/PowerShell   4642
# Python                  4542

# %%
df_Lo['count'].plot(kind='barh', figsize=(9, 6))
plt.title('Top 5 languages most worked with')
plt.ylabel('Languages')
plt.xlabel('Count')

for index, value in enumerate(df_Lo['count']):
    label = format(int(value), ',') 
    plt.annotate(label, xy=(value - 950, index - 0.10), color='white')

plt.show()
#plt.savefig("Top5W.jpg")

# %%
QUERY = """
SELECT *
from DatabaseWorkedWith 
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df_ms=pd.read_sql_query(QUERY,conn)  
#df_ms.set_index('DatabaseWorkedWith', inplace=True) 
df_ms
# Out:
#        Respondent    DatabaseWorkedWith
# 0               4                 MySQL
# 1               4                SQLite
# 2               9              DynamoDB
# 3               9            PostgreSQL
# 4               9                SQLite
# ...           ...                   ...
# 31370       25137                 MySQL
# 31371       25138            PostgreSQL
# 31372       25141  Microsoft SQL Server
# 31373       25141                 Redis
# 31374       25142            PostgreSQL
#
# [31375 rows x 2 columns]

# %%
QUERY = """
SELECT LanguageWorkedWith, COUNT(*) as count 
from LanguageWorkedWith 
group by LanguageWorkedWith
order by count(LanguageWorkedWith) 
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df_Ln=pd.read_sql_query(QUERY,conn)  
df_Ln.set_index('LanguageWorkedWith', inplace=True) 
df_Ln
# Out:
#                        count
# LanguageWorkedWith
# Erlang                    98
# WebAssembly              133
# F#                       158
# Clojure                  164
# Elixir                   187
# Dart                     237
# Rust                     324
# Assembly                 437
# Scala                    492
# Objective-C              518
# R                        585
# VBA                      628
# Swift                    707
# Kotlin                   751
# Other(s):                840
# Go                      1114
# Ruby                    1149
# C                       1578
# C++                     1946
# PHP                     2913
# TypeScript              3232
# C#                      4288
# Java                    4506
# Python                  4542
# Bash/Shell/PowerShell   4642
# SQL                     7106
# HTML/CSS                7830
# JavaScript              8687

# %%
QUERY = """
SELECT DatabaseWorkedWith, COUNT(*) as count 
from DatabaseWorkedWith 
group by DatabaseWorkedWith
order by count(DatabaseWorkedWith) 
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df_dfdn=pd.read_sql_query(QUERY,conn)  
df_dfdn.set_index('DatabaseWorkedWith', inplace=True) 
df_dfdn
# Out:
#                       count
# DatabaseWorkedWith
# Couchbase               250
# Cassandra               397
# Other(s):               728
# DynamoDB                831
# Firebase               1314
# MariaDB                1709
# Oracle                 1744
# Elasticsearch          1954
# Redis                  2508
# MongoDB                3016
# SQLite                 3248
# PostgreSQL             4097
# Microsoft SQL Server   4110
# MySQL                  5469

# %%
QUERY = """
SELECT DatabaseWorkedWith, COUNT(*) as count 
from DatabaseWorkedWith 
group by DatabaseWorkedWith 
order by count(DatabaseWorkedWith) DESC LIMIT 5 
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df_bdn=pd.read_sql_query(QUERY,conn)  
df_bdn.set_index('DatabaseWorkedWith', inplace=True) 
df_bdn
# Out:
#                       count
# DatabaseWorkedWith
# MySQL                  5469
# Microsoft SQL Server   4110
# PostgreSQL             4097
# SQLite                 3248
# MongoDB                3016

# %%
df_bdn['count'].plot(kind='barh', figsize=(9, 6))
plt.title('Top 5 Databases most worked with')
plt.ylabel('Databases')
plt.xlabel('Count')

for index, value in enumerate(df_bdn['count']):
    label = format(int(value), ',') 
    plt.annotate(label, xy=(value - 650, index - 0.10), color='white')

plt.show()

# %%
QUERY = """
SELECT DatabaseDesireNextYear, COUNT(*) as count 
from DatabaseDesireNextYear 
group by DatabaseDesireNextYear 
order by count(DatabaseDesireNextYear) DESC LIMIT 5 
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df_bdny=pd.read_sql_query(QUERY,conn)  
df_bdny.set_index('DatabaseDesireNextYear', inplace=True) 
df_bdny
# Out:
#                         count
# DatabaseDesireNextYear
# PostgreSQL               4328
# MongoDB                  3649
# Redis                    3331
# MySQL                    3281
# Elasticsearch            2856

# %%
df_bdny['count'].plot(kind='barh', figsize=(9, 6))
plt.title('Top 5 most desired Databases for next year')
plt.ylabel('Databases')
plt.xlabel('Count')

for index, value in enumerate(df_bdny['count']):
    label = format(int(value), ',') 
    plt.annotate(label, xy=(value - 450, index - 0.10), color='white')

plt.show()

# %% [markdown]
# Close the database connection.

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
